# %% [markdown]
# <a href="https://colab.research.google.com/github/Jo9gi/FMML-ASSIGNMENTS/blob/main/_Assignment_Recurssion_releation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %% [markdown]
# ![IMG-20240402-WA0080.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 2. Given a recurrence relation, solve it using the substitution method:
#
# a. T(n) = T(n-1) + c
#
# b. T(n) = 2T(n/2) + n
#
# c. T(n) = 2T(n/2) + c
#
# d. T(n) = T(n/2) + c

# %% [markdown]
# **a. T(n) = T(n-1) + c**

# %% [markdown]
# ![IMG-20240402-WA0081.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **b. T(n) = 2T(n/2) + n**

# %% [markdown]
# ![IMG-20240402-WA0082.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **c. T(n) = 2T(n/2) + c**

# %% [markdown]
# ![IMG-20240402-WA0083.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **d. T(n) = T(n/2) + c**

# %% [markdown]
# ![IMG-20240402-WA0084.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **3. Given a recurrence relation, solve it using the recursive tree approach:**
#
# a. T(n) = 2T(n-1) +1
#
# b. T(n) = 2T(n/2) + n

# %% [markdown]
# **a. T(n) = 2T(n-1) +1**

# %% [markdown]
# ![IMG-20240402-WA0086.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **b. T(n) = 2T(n/2) + n**

# %% [markdown]
# ![IMG-20240402-WA0085.jpg](data:image/jpeg;base64,...)
